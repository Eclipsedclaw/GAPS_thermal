fig = plt.figure(figsize = (15, 5))
ax1 = fig.add_subplot(111)
xx = np.linspace(1, 36, num=36)
#plt.axhline(y = -40, color = 'b', linestyle = 'dashed', alpha = 0.3)
#plt.axhline(y = -38, color = 'r', linestyle = 'dashed', alpha = 0.3)
#plt.axhline(y = -36, color = 'g', linestyle = 'dashed', alpha = 0.3)
ax1.scatter(xx, T_0, s=20, c='b', marker="s", label=f'11:43, Feb 7th Oscillation at -42\N{DEGREE SIGN}C, layer average %0.1f\N{DEGREE SIGN}C'%(round(np.average(T_0), 3)))
ax1.set_xticks([])
ax1.scatter(xx, T_1, s=20, c='r', marker="s", label=f'12:22, Feb 7th Oscillation at -42\N{DEGREE SIGN}C, layer average %0.1f\N{DEGREE SIGN}C'%(round(np.average(T_1), 3)))
ax1.scatter(xx, T_2, s=20, c='g', marker="s", label=f'13:09, Feb 7th Oscillation at -42\N{DEGREE SIGN}C, layer average %0.1f\N{DEGREE SIGN}C'%(round(np.average(T_2), 3)))
ax1.scatter(xx, T_3, s=20, c='c', marker="s", label=f'14:56, Feb 7th Oscillation at -42\N{DEGREE SIGN}C, layer average %0.1f\N{DEGREE SIGN}C'%(round(np.average(T_3), 3)))
ax1.scatter(xx, T_4, s=20, c='m', marker="s", label=f'15:53, Feb 7th Oscillation at -41\N{DEGREE SIGN}C, layer average %0.1f\N{DEGREE SIGN}C'%(round(np.average(T_4), 3)))
ax1.scatter(xx, T_5, s=20, c='y', marker="s", label=f'18:25, Feb 7th Oscillation at -41\N{DEGREE SIGN}C, layer average %0.1f\N{DEGREE SIGN}C'%(round(np.average(T_5), 3)))
ax1.scatter(xx, T_6, s=20, c='k', marker="s", label=f'10:20, Feb 8th Oscillation at -41\N{DEGREE SIGN}C, layer average %0.1f\N{DEGREE SIGN}C'%(round(np.average(T_6), 3)))


ax1.set_xlabel('Layer-2\'s modules')
ax1.set_ylabel('Temperature/\N{DEGREE SIGN}C')
ax1.set_title('Cooling performance comparison')
ax1.set_ylim([-42, -25])
#fig.text(0.8, 0.16, 'Oscillation -40\N{DEGREE SIGN}C', color = 'b')
#fig.text(0.8, 0.20, 'Oscillation -38\N{DEGREE SIGN}C', color = 'r')
#fig.text(0.8, 0.25, 'Oscillation -36\N{DEGREE SIGN}C', color = 'g')
plt.legend()
plt.show()

# %%
'''
import csv
with open("data/Feb_6.csv","a") as my_csv:
    csvWriter = csv.writer(my_csv,delimiter=',')
    csvWriter.writerows(T_0)
'''
# Out:
# '\nimport csv\nwith open("data/Feb_6.csv","a") as my_csv:\n    csvWriter = csv.writer(my_csv,delimiter=\',\')\n    csvWriter.writerows(T_0)\n'

# %%
labels = ['Feb 7, 11:43', 'Feb 7, 12:22', 'Feb 7, 13:09', 'Feb 7, 14:56', 'Feb 7, 15:53', 'Feb 7, 18:25', 'Feb 8, 10:20']
t = [11.75, 12.37, 13.15, 14.93, 15.88, 18.42, 34.33]
Time = [time.strptime(t, '%H:%M') for t in ts]
plt.scatter(t, [round(np.average(T_0), 3), round(np.average(T_1), 3), round(np.average(T_2), 3), round(np.average(T_3), 3), round(np.average(T_4), 3), round(np.average(T_5), 3), round(np.average(T_6), 3)])
plt.xlabel('Time on week of Feb 6th')
plt.xticks(t, labels, rotation=90)
plt.ylabel('Temperature/\N{DEGREE SIGN}C')
plt.ylim([-40, -30])
plt.title('Layer-2 average temperature readout after turning on all electronics')
# Out:
# Text(0.5, 1.0, 'Layer-2 average temperature readout after turning on all electronics')
