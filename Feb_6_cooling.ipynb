# %%
"""
Display tracker temperature for Feb 6 run
Aur: Jiancheng Zeng
Date: Feb 7, 2023
"""
# Out:
# '\nDisplay tracker temperature for Feb 6 run\nAur: Jiancheng Zeng\nDate: Feb 7, 2023\n'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from pylab import *
from matplotlib.pyplot import figure

# %%
'''
Even layer = [[05, 04, 03, 02, 01, 00], [15, 14, 13, 12, 11, 10], [25, 24, 23, 22, 21, 20], [35, 34, 33, 32, 31, 30], [45, 44, 43, 42, 41, 40], [55, 54, 53, 52, 51, 50]]
Odd layer = [[05, 15, 25, 35, 45, 55], [04, 14, 24, 34, 44, 54], [03, 13, 23, 33, 43, 53], [02, 12, 22, 32, 42, 52], [01, 11, 21, 31, 41, 51], [00, 10, 20, 30, 40, 50]]
'''

'''
Layer-0 ASIC temperature
'''
T_0=np.array([[-30.11, -34.00, -35.19, -35.03, -36.94, -36.30], [-30.27, -35.67, -35.59, -35.03, -37.57, -36.46], [-28.76, -33.84, -35.35, -35.35, -35.67, -37.10], [-27.97, -34.87, -36.86, -34.40, -36.62, -36.86], [-25.67, -30.51, -34.08, -34.00, -36.46, -33.52], [-17.10, -25.43, -29.00, -30.59, -29.87, -26.30]])

'''
Layer-1 ASIC temperature
'''
T_1=np.array([[]])
'''
Layer-2 ASIC temperature
'''
T_2=np.array([[-35.90, -36.46, -39.71, -39.40, -39.40, -37.17], [-36.70, -39.63, -39.79, -39.63, -40.27, -38.92], [-36.94, -39.40, -40.98, -40.19, -38.76, -38.76], [-36.38, -38.29, -38.68, -40.03, -39.56, -37.25], [-33.68, -36.78, -37.89, -37.81, -38.29, -36.86], [-31.22, -35.11, -35.83, -36.86, -35.90, -34.16]])

'''
Layer-3 ASIC temperature
'''
T_3=np.array([[]])
'''
Layer-4 ASIC temperature
'''
T_4=np.array([[]])
'''
Layer-5 ASIC temperature
'''
T_5=np.array([[]])
'''
Layer-6 ASIC temperature
'''
T_6=np.array([[]])
'''
dummy layers
'''
T_7=np.array([404]*36)
T_8=np.array([404]*36)
T_9=np.array([404]*36)

'''
Entire tracker temperature
'''
T=np.array([T_0, T_1, T_2, T_3, T_4, T_5, T_6, T_7, T_8, T_9]);
# Out:
# /tmp/ipykernel_2602917/658098966.py:46: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   T=np.array([T_0, T_1, T_2, T_3, T_4, T_5, T_6, T_7, T_8, T_9]);

# %%
fig = plt.figure(figsize=(6, 6.4))
ax = fig.add_subplot(111)
ax.set_title('Feb 7th Layer-0 temperature TOP view \n Radiator side')
ax.set_aspect('equal')
ax.set_xlabel('OHP Oscillate at -40 degree-C \n layer average temperature ' + str(round(np.average(T_0),1)) + 'C')
plt.imshow(T_0, cmap = 'winter', vmin = -40, vmax = -15)
cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
cax.get_xaxis().set_visible(False)
cax.get_yaxis().set_visible(False)
cax.patch.set_alpha(0)
cax.set_frame_on(False)
plt.colorbar(orientation='vertical', label='\N{DEGREE SIGN}C')

'''
Put temperature on the blocks
'''
for (j,i),label in np.ndenumerate(T_0):
    ax.text(i,j,round(T_0[j, i],1), c='k', ha='center',va='center')
    
plt.show()

# %%
fig = plt.figure(figsize=(6, 6.4))

ax = fig.add_subplot(111)
ax.set_title('Feb 7th Layer-2 temperature TOP view \n Radiator side')
ax.set_aspect('equal')
ax.set_xlabel('OHP Oscillate at -42 degree-C \n layer average temperature ' + str(round(np.average(T_2),1)) + 'C')
plt.imshow(T_2, cmap = 'winter', vmin = -40, vmax = -15)
cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
cax.get_xaxis().set_visible(False)
cax.get_yaxis().set_visible(False)
cax.patch.set_alpha(0)
cax.set_frame_on(False)
plt.colorbar(orientation='vertical', label='\N{DEGREE SIGN}C')

'''
Put temperature on the blocks
'''
for (j,i),label in np.ndenumerate(T_2):
    ax.text(i,j,round(T_2[j, i],1), c='k', ha='center',va='center')
    
plt.show()
